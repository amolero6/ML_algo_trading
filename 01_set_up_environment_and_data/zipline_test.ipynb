# %%
import os
import warnings
warnings.filterwarnings('ignore')
os.environ['QUANDL_API_KEY'] = 'BtMxMFzJQ7NKCq9yR5Cz'

# %%
# !zipline ingest
# Out:
# [2023-07-08 08:30:29.468239] INFO: zipline.data.bundles.core: Ingesting quandl.
# [2023-07-08 08:30:29.468400] INFO: zipline.data.bundles.quandl: Downloading WIKI metadata.
# Downloading WIKI Prices table from Quandl  [####################################]  100%
# [2023-07-08 08:33:55.040888] INFO: zipline.data.bundles.quandl: Parsing raw data.
# [2023-07-08 08:34:19.709172] INFO: zipline.data.bundles.quandl: Generating asset metadata.
# Merging daily equity files:  [--------------------#---------------]  1731/Users/Adri/opt/miniconda3/envs/liveproject/lib/python3.8/site-packages/zipline/data/bcolz_daily_bars.py:366: UserWarning: Ignoring 1 values because they are out of bounds for uint32:             open  high   low  close        volume  ex_dividend  split_ratio
# 2011-04-11  1.79  1.84  1.55    1.7  6.674913e+09          0.0          1.0
#   winsorise_uint32(raw_data, invalid_data_behavior, "volume", *OHLC)
# Merging daily equity files:  [####################################]
# [2023-07-08 08:36:06.122535] INFO: zipline.data.bundles.quandl: Parsing split data.
# [2023-07-08 08:36:06.287055] INFO: zipline.data.bundles.quandl: Parsing dividend data.
# [2023-07-08 08:36:08.852369] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=67, ex_date=2017-11-09, amount=0.620
# [2023-07-08 08:36:08.852534] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=93, ex_date=2017-11-09, amount=0.240
# [2023-07-08 08:36:08.852615] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=161, ex_date=2017-11-09, amount=0.110
# [2023-07-08 08:36:08.852686] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=283, ex_date=2017-11-09, amount=0.415
# [2023-07-08 08:36:08.852744] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=298, ex_date=2017-11-09, amount=1.420
# [2023-07-08 08:36:08.852809] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=318, ex_date=2017-11-09, amount=0.330
# [2023-07-08 08:36:08.852860] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=434, ex_date=2017-11-09, amount=0.110
# [2023-07-08 08:36:08.852921] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=516, ex_date=1996-05-30, amount=0.310
# [2023-07-08 08:36:08.852971] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=524, ex_date=2017-11-09, amount=0.050
# [2023-07-08 08:36:08.853030] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=556, ex_date=2017-11-09, amount=0.075
# [2023-07-08 08:36:08.853078] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=578, ex_date=2017-11-09, amount=0.160
# [2023-07-08 08:36:08.853138] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=605, ex_date=2017-11-09, amount=0.040
# [2023-07-08 08:36:08.853196] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=666, ex_date=1990-03-26, amount=0.140
# [2023-07-08 08:36:08.853245] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=694, ex_date=1990-03-27, amount=0.100
# [2023-07-08 08:36:08.853303] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=723, ex_date=2017-11-09, amount=1.620
# [2023-07-08 08:36:08.853363] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=758, ex_date=2017-11-09, amount=0.500
# [2023-07-08 08:36:08.853411] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=788, ex_date=2017-11-09, amount=0.060
# [2023-07-08 08:36:08.853459] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=859, ex_date=1995-05-09, amount=0.100
# [2023-07-08 08:36:08.853519] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=904, ex_date=2017-11-09, amount=0.135
# [2023-07-08 08:36:08.853576] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=975, ex_date=2017-11-09, amount=0.030
# [2023-07-08 08:36:08.853625] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=1057, ex_date=2017-11-09, amount=0.250
# [2023-07-08 08:36:08.853684] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=1088, ex_date=1990-03-26, amount=0.240
# [2023-07-08 08:36:08.853743] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=1091, ex_date=2017-11-09, amount=0.075
# [2023-07-08 08:36:08.853791] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=1111, ex_date=1993-03-04, amount=0.070
# [2023-07-08 08:36:08.853849] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=1172, ex_date=2017-11-09, amount=0.130
# [2023-07-08 08:36:08.853898] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=1209, ex_date=2017-11-09, amount=0.010
# [2023-07-08 08:36:08.853955] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=1322, ex_date=1995-05-25, amount=0.150
# [2023-07-08 08:36:08.854002] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=1441, ex_date=2017-11-09, amount=1.500
# [2023-07-08 08:36:08.854061] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=1525, ex_date=2017-11-09, amount=0.090
# [2023-07-08 08:36:08.854120] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=1600, ex_date=2015-07-06, amount=16.500
# [2023-07-08 08:36:08.854168] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=1642, ex_date=2017-11-09, amount=0.270
# [2023-07-08 08:36:08.854227] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=1748, ex_date=2017-11-09, amount=0.740
# [2023-07-08 08:36:08.854275] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=1876, ex_date=2017-11-09, amount=0.120
# [2023-07-08 08:36:08.854333] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=1922, ex_date=2017-11-09, amount=0.040
# [2023-07-08 08:36:08.854381] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=1947, ex_date=1990-03-26, amount=0.150
# [2023-07-08 08:36:08.854439] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=2098, ex_date=2017-11-09, amount=0.200
# [2023-07-08 08:36:08.854497] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=2118, ex_date=2014-11-06, amount=0.050
# [2023-07-08 08:36:08.854544] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=2120, ex_date=2017-11-09, amount=0.110
# [2023-07-08 08:36:08.854602] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=2149, ex_date=2017-11-09, amount=0.330
# [2023-07-08 08:36:08.854650] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=2204, ex_date=2017-11-09, amount=0.320
# [2023-07-08 08:36:08.854707] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=2220, ex_date=2017-11-09, amount=0.660
# [2023-07-08 08:36:08.854754] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=2281, ex_date=2017-11-09, amount=0.450
# [2023-07-08 08:36:08.854813] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=2389, ex_date=2017-11-09, amount=0.140
# [2023-07-08 08:36:08.854870] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=2441, ex_date=2017-11-09, amount=0.215
# [2023-07-08 08:36:08.854918] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=2517, ex_date=2017-11-09, amount=0.080
# [2023-07-08 08:36:08.854975] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=2582, ex_date=2017-11-09, amount=0.780
# [2023-07-08 08:36:08.855024] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=2622, ex_date=2017-11-09, amount=0.390
# [2023-07-08 08:36:08.855081] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=2662, ex_date=2015-01-14, amount=0.750
# [2023-07-08 08:36:08.855129] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=2754, ex_date=2000-12-27, amount=0.250
# [2023-07-08 08:36:08.855187] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=2754, ex_date=2009-09-11, amount=0.420
# [2023-07-08 08:36:08.855245] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=2754, ex_date=2009-12-11, amount=0.420
# [2023-07-08 08:36:08.855293] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=2754, ex_date=2010-03-11, amount=0.420
# [2023-07-08 08:36:08.855351] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=2754, ex_date=2010-12-15, amount=0.180
# [2023-07-08 08:36:08.855408] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=2766, ex_date=2017-11-09, amount=0.320
# [2023-07-08 08:36:08.855455] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=2798, ex_date=2017-11-09, amount=0.065
# [2023-07-08 08:36:08.855514] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=2817, ex_date=1992-03-03, amount=0.300
# [2023-07-08 08:36:08.855572] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=2824, ex_date=2017-11-09, amount=0.120
# [2023-07-08 08:36:08.855619] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=2843, ex_date=2017-11-09, amount=0.150
# [2023-07-08 08:36:08.855677] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=2857, ex_date=2011-09-07, amount=0.410
# [2023-07-08 08:36:08.855735] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=2968, ex_date=1990-03-26, amount=0.100
# [2023-07-08 08:36:08.855782] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=3005, ex_date=1990-03-26, amount=0.070
# [2023-07-08 08:36:08.855840] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=3078, ex_date=2014-05-12, amount=0.060
# [2023-07-08 08:36:08.855898] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=3117, ex_date=2017-11-09, amount=0.430
# [2023-07-08 08:36:08.855946] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=3138, ex_date=2010-08-16, amount=0.060
# [2023-07-08 08:36:08.856004] WARNING: zipline.data.adjustments: Couldn't compute ratio for dividend sid=3145, ex_date=2017-11-09, amount=0.050
# [2023-07-08 08:36:08.856294] WARNING: zipline.data.adjustments: Dividend ratio <= 0 for dividend sid=501, ex_date=2006-01-03, amount=41.560
# [2023-07-08 08:36:08.856375] WARNING: zipline.data.adjustments: Dividend ratio <= 0 for dividend sid=1557, ex_date=2007-07-02, amount=88.530
# [2023-07-08 08:36:08.856426] WARNING: zipline.data.adjustments: Dividend ratio <= 0 for dividend sid=1632, ex_date=2000-07-13, amount=181.000
# [2023-07-08 08:36:08.856475] WARNING: zipline.data.adjustments: Dividend ratio <= 0 for dividend sid=1657, ex_date=2013-09-30, amount=21.355
# [2023-07-08 08:36:08.856546] WARNING: zipline.data.adjustments: Dividend ratio <= 0 for dividend sid=1775, ex_date=1994-12-01, amount=76.000
# [2023-07-08 08:36:08.856595] WARNING: zipline.data.adjustments: Dividend ratio <= 0 for dividend sid=1776, ex_date=1996-11-04, amount=36.708
# [2023-07-08 08:36:08.856643] WARNING: zipline.data.adjustments: Dividend ratio <= 0 for dividend sid=2455, ex_date=2016-10-03, amount=25.611
# [2023-07-08 08:36:08.856713] WARNING: zipline.data.adjustments: Dividend ratio <= 0 for dividend sid=2687, ex_date=2008-06-26, amount=10.000
# [2023-07-08 08:36:08.856761] WARNING: zipline.data.adjustments: Dividend ratio <= 0 for dividend sid=2900, ex_date=2007-07-02, amount=88.530
# [2023-07-08 08:36:08.856819] WARNING: zipline.data.adjustments: Dividend ratio <= 0 for dividend sid=3088, ex_date=2015-04-27, amount=31.291

# %%
# !zipline bundles
# Out:
# csvdir <no ingestions>
# quandl 2023-07-08 08:30:28.924969
# quandl 2023-07-08 07:48:57.891171
# quantopian-quandl <no ingestions>

# %%
#For Jupyter Notebook

# %%
# %load_ext zipline

# %%
# %%zipline --start 2014-1-1 --end 2018-1-1 --no-benchmark -o dma.pickle
#
#
# from zipline.api import order_target, record, symbol
# import matplotlib.pyplot as plt
#
# def initialize(context):
#     context.i = 0
#     context.asset = symbol('AAPL')
#
#
# def handle_data(context, data):
#     # Skip first 300 days to get full windows
#     context.i += 1
#     if context.i < 300:
#         return
#
#     # Compute averages
#     # data.history() has to be called with the same params
#     # from above and returns a pandas dataframe.
#     short_mavg = data.history(context.asset, 'price', bar_count=100, frequency="1d").mean()
#     long_mavg = data.history(context.asset, 'price', bar_count=300, frequency="1d").mean()
#
#     # Trading logic
#     if short_mavg > long_mavg:
#         # order_target orders as many shares as needed to
#         # achieve the desired number of shares.
#         order_target(context.asset, 100)
#     elif short_mavg < long_mavg:
#         order_target(context.asset, 0)
#
#     # Save values for later inspection
#     record(AAPL=data.current(context.asset, 'price'),
#            short_mavg=short_mavg,
#            long_mavg=long_mavg)
#
#
# def analyze(context, perf):
#     fig = plt.figure()
#     ax1 = fig.add_subplot(211)
#     perf.portfolio_value.plot(ax=ax1)
#     ax1.set_ylabel('portfolio value in $')
#
#     ax2 = fig.add_subplot(212,sharex=ax1)
#     perf['AAPL'].plot(ax=ax2)
#     perf[['short_mavg', 'long_mavg']].plot(ax=ax2)
#
#     perf_trans = perf.loc[[t != [] for t in perf.transactions]]
#     buys = perf_trans.loc[[t[0]['amount'] > 0 for t in perf_trans.transactions]]
#     sells = perf_trans.loc[
#         [t[0]['amount'] < 0 for t in perf_trans.transactions]]
#     ax2.plot(buys.index, perf.short_mavg.loc[buys.index],
#              '^', markersize=10, color='m')
#     ax2.plot(sells.index, perf.short_mavg.loc[sells.index],
#              'v', markersize=10, color='k')
#     ax2.set_ylabel('price in $')
#     plt.legend(loc=0)
#     plt.show()
# Out:
#                                         period_open              period_close  \
# 2014-01-02 21:00:00+00:00 2014-01-02 14:31:00+00:00 2014-01-02 21:00:00+00:00
# 2014-01-03 21:00:00+00:00 2014-01-03 14:31:00+00:00 2014-01-03 21:00:00+00:00
# 2014-01-06 21:00:00+00:00 2014-01-06 14:31:00+00:00 2014-01-06 21:00:00+00:00
# 2014-01-07 21:00:00+00:00 2014-01-07 14:31:00+00:00 2014-01-07 21:00:00+00:00
# 2014-01-08 21:00:00+00:00 2014-01-08 14:31:00+00:00 2014-01-08 21:00:00+00:00
# ...                                             ...                       ...
# 2017-12-22 21:00:00+00:00 2017-12-22 14:31:00+00:00 2017-12-22 21:00:00+00:00
# 2017-12-26 21:00:00+00:00 2017-12-26 14:31:00+00:00 2017-12-26 21:00:00+00:00
# 2017-12-27 21:00:00+00:00 2017-12-27 14:31:00+00:00 2017-12-27 21:00:00+00:00
# 2017-12-28 21:00:00+00:00 2017-12-28 14:31:00+00:00 2017-12-28 21:00:00+00:00
# 2017-12-29 21:00:00+00:00 2017-12-29 14:31:00+00:00 2017-12-29 21:00:00+00:00
#
#                            starting_cash   ending_cash  portfolio_value  \
# 2014-01-02 21:00:00+00:00   1.000000e+07  1.000000e+07     1.000000e+07
# 2014-01-03 21:00:00+00:00   1.000000e+07  1.000000e+07     1.000000e+07
# 2014-01-06 21:00:00+00:00   1.000000e+07  1.000000e+07     1.000000e+07
# 2014-01-07 21:00:00+00:00   1.000000e+07  1.000000e+07     1.000000e+07
# 2014-01-08 21:00:00+00:00   1.000000e+07  1.000000e+07     1.000000e+07
# ...                                  ...           ...              ...
# 2017-12-22 21:00:00+00:00   9.987736e+06  9.987736e+06     1.000524e+07
# 2017-12-26 21:00:00+00:00   9.987736e+06  9.987736e+06     1.000479e+07
# 2017-12-27 21:00:00+00:00   9.987736e+06  9.987736e+06     1.000480e+07
# 2017-12-28 21:00:00+00:00   9.987736e+06  9.987736e+06     1.000484e+07
# 2017-12-29 21:00:00+00:00   9.987736e+06  9.987736e+06     1.000466e+07
#
#                            longs_count  shorts_count  long_value  short_value  \
# 2014-01-02 21:00:00+00:00            0             0         0.0          0.0
# 2014-01-03 21:00:00+00:00            0             0         0.0          0.0
# 2014-01-06 21:00:00+00:00            0             0         0.0          0.0
# 2014-01-07 21:00:00+00:00            0             0         0.0          0.0
# 2014-01-08 21:00:00+00:00            0             0         0.0          0.0
# ...                                ...           ...         ...          ...
# 2017-12-22 21:00:00+00:00            1             0     17501.0          0.0
# 2017-12-26 21:00:00+00:00            1             0     17057.0          0.0
# 2017-12-27 21:00:00+00:00            1             0     17060.0          0.0
# 2017-12-28 21:00:00+00:00            1             0     17108.0          0.0
# 2017-12-29 21:00:00+00:00            1             0     16923.0          0.0
#
#                                 returns  ...  alpha  beta    sharpe   sortino  \
# 2014-01-02 21:00:00+00:00  0.000000e+00  ...   None  None       NaN       NaN
# 2014-01-03 21:00:00+00:00  0.000000e+00  ...   None  None       NaN       NaN
# 2014-01-06 21:00:00+00:00  0.000000e+00  ...   None  None       NaN       NaN
# 2014-01-07 21:00:00+00:00  0.000000e+00  ...   None  None       NaN       NaN
# 2014-01-08 21:00:00+00:00  0.000000e+00  ...   None  None       NaN       NaN
# ...                                 ...  ...    ...   ...       ...       ...
# 2017-12-22 21:00:00+00:00  0.000000e+00  ...   None  None  0.687600  1.012820
# 2017-12-26 21:00:00+00:00 -4.437676e-05  ...   None  None  0.624704  0.913225
# 2017-12-27 21:00:00+00:00  2.998563e-07  ...   None  None  0.624784  0.913342
# 2017-12-28 21:00:00+00:00  4.797699e-06  ...   None  None  0.630682  0.922021
# 2017-12-29 21:00:00+00:00 -1.849104e-05  ...   None  None  0.605565  0.884195
#
#                           max_drawdown max_leverage excess_return    AAPL  \
# 2014-01-02 21:00:00+00:00     0.000000     0.000000           0.0     NaN
# 2014-01-03 21:00:00+00:00     0.000000     0.000000           0.0     NaN
# 2014-01-06 21:00:00+00:00     0.000000     0.000000           0.0     NaN
# 2014-01-07 21:00:00+00:00     0.000000     0.000000           0.0     NaN
# 2014-01-08 21:00:00+00:00     0.000000     0.000000           0.0     NaN
# ...                                ...          ...           ...     ...
# 2017-12-22 21:00:00+00:00    -0.000295     0.001763           0.0  175.01
# 2017-12-26 21:00:00+00:00    -0.000295     0.001763           0.0  170.57
# 2017-12-27 21:00:00+00:00    -0.000295     0.001763           0.0  170.60
# 2017-12-28 21:00:00+00:00    -0.000295     0.001763           0.0  171.08
# 2017-12-29 21:00:00+00:00    -0.000295     0.001763           0.0  169.23
#
#                            short_mavg   long_mavg
# 2014-01-02 21:00:00+00:00         NaN         NaN
# 2014-01-03 21:00:00+00:00         NaN         NaN
# 2014-01-06 21:00:00+00:00         NaN         NaN
# 2014-01-07 21:00:00+00:00         NaN         NaN
# 2014-01-08 21:00:00+00:00         NaN         NaN
# ...                               ...         ...
# 2017-12-22 21:00:00+00:00  163.442190  142.891860
# 2017-12-26 21:00:00+00:00  163.598280  143.075387
# 2017-12-27 21:00:00+00:00  163.746503  143.259273
# 2017-12-28 21:00:00+00:00  163.899520  143.445907
# 2017-12-29 21:00:00+00:00  163.997280  143.626570
#
# [1007 rows x 40 columns]

# %%
# for IDE

# %%
from zipline import run_algorithm
import pandas as pd
import pandas_datareader.data as web
from zipline.api import order_target, record, symbol


def initialize(context):
    context.i = 0
    context.asset = symbol('AAPL')


def handle_data(context, data):
    # Skip first 300 days to get full windows
    context.i += 1
    if context.i < 300:
        return

    # Compute averages
    # data.history() has to be called with the same params
    # from above and returns a pandas dataframe.
    short_mavg = data.history(context.asset, 'price', bar_count=100, frequency="1d").mean()
    long_mavg = data.history(context.asset, 'price', bar_count=300, frequency="1d").mean()

    # Trading logic
    if short_mavg > long_mavg:
        # order_target orders as many shares as needed to
        # achieve the desired number of shares.
        order_target(context.asset, 100)
    elif short_mavg < long_mavg:
        order_target(context.asset, 0)

    # Save values for later inspection
    record(AAPL=data.current(context.asset, 'price'),
           short_mavg=short_mavg,
           long_mavg=long_mavg)

start = pd.Timestamp('2014')
end = pd.Timestamp('2018')

sp500 = web.DataReader('SP500', 'fred', start, end).SP500
benchmark_returns = sp500.pct_change()

result = run_algorithm(start=start.tz_localize('UTC'),
                       end=end.tz_localize('UTC'),
                       initialize=initialize,
                       handle_data=handle_data,
                       capital_base=100000,
                       benchmark_returns=benchmark_returns,
                       bundle='quandl',
                       data_frequency='daily')

# %%
result
# Out:
#                                         period_open              period_close  \
# 2014-01-02 21:00:00+00:00 2014-01-02 14:31:00+00:00 2014-01-02 21:00:00+00:00
# 2014-01-03 21:00:00+00:00 2014-01-03 14:31:00+00:00 2014-01-03 21:00:00+00:00
# 2014-01-06 21:00:00+00:00 2014-01-06 14:31:00+00:00 2014-01-06 21:00:00+00:00
# 2014-01-07 21:00:00+00:00 2014-01-07 14:31:00+00:00 2014-01-07 21:00:00+00:00
# 2014-01-08 21:00:00+00:00 2014-01-08 14:31:00+00:00 2014-01-08 21:00:00+00:00
# ...                                             ...                       ...
# 2017-12-22 21:00:00+00:00 2017-12-22 14:31:00+00:00 2017-12-22 21:00:00+00:00
# 2017-12-26 21:00:00+00:00 2017-12-26 14:31:00+00:00 2017-12-26 21:00:00+00:00
# 2017-12-27 21:00:00+00:00 2017-12-27 14:31:00+00:00 2017-12-27 21:00:00+00:00
# 2017-12-28 21:00:00+00:00 2017-12-28 14:31:00+00:00 2017-12-28 21:00:00+00:00
# 2017-12-29 21:00:00+00:00 2017-12-29 14:31:00+00:00 2017-12-29 21:00:00+00:00
#
#                            ending_cash  gross_leverage  ending_value  \
# 2014-01-02 21:00:00+00:00   100000.000        0.000000           0.0
# 2014-01-03 21:00:00+00:00   100000.000        0.000000           0.0
# 2014-01-06 21:00:00+00:00   100000.000        0.000000           0.0
# 2014-01-07 21:00:00+00:00   100000.000        0.000000           0.0
# 2014-01-08 21:00:00+00:00   100000.000        0.000000           0.0
# ...                                ...             ...           ...
# 2017-12-22 21:00:00+00:00    87735.699        0.166301       17501.0
# 2017-12-26 21:00:00+00:00    87735.699        0.162769       17057.0
# 2017-12-27 21:00:00+00:00    87735.699        0.162793       17060.0
# 2017-12-28 21:00:00+00:00    87735.699        0.163176       17108.0
# 2017-12-29 21:00:00+00:00    87735.699        0.161697       16923.0
#
#                            starting_value  shorts_count  ending_exposure  \
# 2014-01-02 21:00:00+00:00             0.0             0              0.0
# 2014-01-03 21:00:00+00:00             0.0             0              0.0
# 2014-01-06 21:00:00+00:00             0.0             0              0.0
# 2014-01-07 21:00:00+00:00             0.0             0              0.0
# 2014-01-08 21:00:00+00:00             0.0             0              0.0
# ...                                   ...           ...              ...
# 2017-12-22 21:00:00+00:00         17501.0             0          17501.0
# 2017-12-26 21:00:00+00:00         17501.0             0          17057.0
# 2017-12-27 21:00:00+00:00         17057.0             0          17060.0
# 2017-12-28 21:00:00+00:00         17060.0             0          17108.0
# 2017-12-29 21:00:00+00:00         17108.0             0          16923.0
#
#                            longs_count  long_value  ...  excess_return  \
# 2014-01-02 21:00:00+00:00            0         0.0  ...            0.0
# 2014-01-03 21:00:00+00:00            0         0.0  ...            0.0
# 2014-01-06 21:00:00+00:00            0         0.0  ...            0.0
# 2014-01-07 21:00:00+00:00            0         0.0  ...            0.0
# 2014-01-08 21:00:00+00:00            0         0.0  ...            0.0
# ...                                ...         ...  ...            ...
# 2017-12-22 21:00:00+00:00            1     17501.0  ...            0.0
# 2017-12-26 21:00:00+00:00            1     17057.0  ...            0.0
# 2017-12-27 21:00:00+00:00            1     17060.0  ...            0.0
# 2017-12-28 21:00:00+00:00            1     17108.0  ...            0.0
# 2017-12-29 21:00:00+00:00            1     16923.0  ...            0.0
#
#                           treasury_period_return  trading_days  period_label  \
# 2014-01-02 21:00:00+00:00                    0.0             1       2014-01
# 2014-01-03 21:00:00+00:00                    0.0             2       2014-01
# 2014-01-06 21:00:00+00:00                    0.0             3       2014-01
# 2014-01-07 21:00:00+00:00                    0.0             4       2014-01
# 2014-01-08 21:00:00+00:00                    0.0             5       2014-01
# ...                                          ...           ...           ...
# 2017-12-22 21:00:00+00:00                    0.0          1003       2017-12
# 2017-12-26 21:00:00+00:00                    0.0          1004       2017-12
# 2017-12-27 21:00:00+00:00                    0.0          1005       2017-12
# 2017-12-28 21:00:00+00:00                    0.0          1006       2017-12
# 2017-12-29 21:00:00+00:00                    0.0          1007       2017-12
#
#                            benchmark_period_return benchmark_volatility  \
# 2014-01-02 21:00:00+00:00                      0.0                  NaN
# 2014-01-03 21:00:00+00:00                      0.0                  0.0
# 2014-01-06 21:00:00+00:00                      0.0                  0.0
# 2014-01-07 21:00:00+00:00                      0.0                  0.0
# 2014-01-08 21:00:00+00:00                      0.0                  0.0
# ...                                            ...                  ...
# 2017-12-22 21:00:00+00:00                      0.0                  0.0
# 2017-12-26 21:00:00+00:00                      0.0                  0.0
# 2017-12-27 21:00:00+00:00                      0.0                  0.0
# 2017-12-28 21:00:00+00:00                      0.0                  0.0
# 2017-12-29 21:00:00+00:00                      0.0                  0.0
#
#                            algorithm_period_return    AAPL  short_mavg  \
# 2014-01-02 21:00:00+00:00                 0.000000     NaN         NaN
# 2014-01-03 21:00:00+00:00                 0.000000     NaN         NaN
# 2014-01-06 21:00:00+00:00                 0.000000     NaN         NaN
# 2014-01-07 21:00:00+00:00                 0.000000     NaN         NaN
# 2014-01-08 21:00:00+00:00                 0.000000     NaN         NaN
# ...                                            ...     ...         ...
# 2017-12-22 21:00:00+00:00                 0.052367  175.01  163.442190
# 2017-12-26 21:00:00+00:00                 0.047927  170.57  163.598280
# 2017-12-27 21:00:00+00:00                 0.047957  170.60  163.746503
# 2017-12-28 21:00:00+00:00                 0.048437  171.08  163.899520
# 2017-12-29 21:00:00+00:00                 0.046587  169.23  163.997280
#
#                             long_mavg
# 2014-01-02 21:00:00+00:00         NaN
# 2014-01-03 21:00:00+00:00         NaN
# 2014-01-06 21:00:00+00:00         NaN
# 2014-01-07 21:00:00+00:00         NaN
# 2014-01-08 21:00:00+00:00         NaN
# ...                               ...
# 2017-12-22 21:00:00+00:00  142.891860
# 2017-12-26 21:00:00+00:00  143.075387
# 2017-12-27 21:00:00+00:00  143.259273
# 2017-12-28 21:00:00+00:00  143.445907
# 2017-12-29 21:00:00+00:00  143.626570
#
# [1007 rows x 40 columns]
